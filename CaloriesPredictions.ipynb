# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./Datasets/exercise.csv')

# %%
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# User_ID       0
# Gender        0
# Age           0
# Height        0
# Weight        0
# Duration      0
# Heart_Rate    0
# Body_Temp     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 937.6+ KB

# %%
calories_dataset= pd.read_csv('./Datasets/calories.csv')

# %%
calories_dataset
# Out:
#         User_ID  Calories
# 0      14733363     231.0
# 1      14861698      66.0
# 2      11179863      26.0
# 3      16180408      71.0
# 4      17771927      35.0
# ...         ...       ...
# 14995  15644082      45.0
# 14996  17212577      23.0
# 14997  17271188      75.0
# 14998  18643037      11.0
# 14999  11751526      98.0
#
# [15000 rows x 2 columns]

# %%
df = pd.concat([df,calories_dataset['Calories']],axis=1)

# %%
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363    male   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698  female   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863    male   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408  female   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927  female   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082  female   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577  female   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188  female   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037    male   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526    male   63   173.0    79.0      18.0        92.0       40.5
#
#        Calories
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_ID     15000 non-null  int64
#  1   Gender      15000 non-null  object
#  2   Age         15000 non-null  int64
#  3   Height      15000 non-null  float64
#  4   Weight      15000 non-null  float64
#  5   Duration    15000 non-null  float64
#  6   Heart_Rate  15000 non-null  float64
#  7   Body_Temp   15000 non-null  float64
#  8   Calories    15000 non-null  float64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#             User_ID           Age        Height        Weight      Duration  \
# count  1.500000e+04  15000.000000  15000.000000  15000.000000  15000.000000
# mean   1.497736e+07     42.789800    174.465133     74.966867     15.530600
# std    2.872851e+06     16.980264     14.258114     15.035657      8.319203
# min    1.000116e+07     20.000000    123.000000     36.000000      1.000000
# 25%    1.247419e+07     28.000000    164.000000     63.000000      8.000000
# 50%    1.499728e+07     39.000000    175.000000     74.000000     16.000000
# 75%    1.744928e+07     56.000000    185.000000     87.000000     23.000000
# max    1.999965e+07     79.000000    222.000000    132.000000     30.000000
#
#          Heart_Rate     Body_Temp      Calories
# count  15000.000000  15000.000000  15000.000000
# mean      95.518533     40.025453     89.539533
# std        9.583328      0.779230     62.456978
# min       67.000000     37.100000      1.000000
# ...

# %%
sns.pairplot(df)

# %%
df.replace({'Gender':{'male':0 , 'female':1}} , inplace =True)

# %%
sns.set()
sns.distplot(df['Age'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16660\180995729.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories'],
#       dtype='object')

# %%
sns.displot(data=df['Gender'])

# %%
sns.distplot(df['Height'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16660\3945773010.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Height'])
# <Axes: xlabel='Height', ylabel='Density'>

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16660\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.distplot(df['Duration'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16660\1351347043.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Duration'])
# <Axes: xlabel='Duration', ylabel='Density'>

# %%
sns.distplot(df['Heart_Rate'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16660\4154507538.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Heart_Rate'])
# <Axes: xlabel='Heart_Rate', ylabel='Density'>

# %%
sns.distplot(df['Body_Temp'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_16660\3220751949.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Body_Temp'])
# <Axes: xlabel='Body_Temp', ylabel='Density'>

# %%
df.corr()['Calories'].sort_values()
# Out:
# Gender       -0.022357
# User_ID      -0.001661
# Height        0.017537
# Weight        0.035481
# Age           0.154395
# Body_Temp     0.824558
# Heart_Rate    0.897882
# Duration      0.955421
# Calories      1.000000
# Name: Calories, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.displot(df["Calories"])

# %%
sns.scatterplot(x='Duration' , y='Calories' , data=df)
# Out:
# <Axes: xlabel='Duration', ylabel='Calories'>

# %%
sns.scatterplot(x='Heart_Rate' , y='Calories' , data=df)
# Out:
# <Axes: xlabel='Heart_Rate', ylabel='Calories'>

# %%
X = df.drop(['User_ID','Calories'],axis=1)

# %%
y=df['Calories']

# %%
X
# Out:
#        Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0           0   68   190.0    94.0      29.0       105.0       40.8
# 1           1   20   166.0    60.0      14.0        94.0       40.3
# 2           0   69   179.0    79.0       5.0        88.0       38.7
# 3           1   34   179.0    71.0      13.0       100.0       40.5
# 4           1   27   154.0    58.0      10.0        81.0       39.8
# ...       ...  ...     ...     ...       ...         ...        ...
# 14995       1   20   193.0    86.0      11.0        92.0       40.4
# 14996       1   27   165.0    65.0       6.0        85.0       39.2
# 14997       1   43   159.0    58.0      16.0        90.0       40.1
# 14998       0   78   193.0    97.0       2.0        84.0       38.3
# 14999       0   63   173.0    79.0      18.0        92.0       40.5
#
# [15000 rows x 7 columns]

# %%
y
# Out:
# 0        231.0
# 1         66.0
# 2         26.0
# 3         71.0
# 4         35.0
#          ...
# 14995     45.0
# 14996     23.0
# 14997     75.0
# 14998     11.0
# 14999     98.0
# Name: Calories, Length: 15000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (15000, 7) (12000, 7) (3000, 7) (12000,) (3000,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler =StandardScaler()

# %%
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
df['Calories'].mean()
# Out:
# 89.53953333333334

# %%
sns.histplot(data=df,x='Calories',bins=20)
# Out:
# <Axes: xlabel='Calories', ylabel='Count'>

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 8.385188053147187

# %%
#RMSE
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 11.40557205325028

# %%
model.coef_
# Out:
# array([  1.4198873 ,   0.4971492 ,  -0.19413313,   0.31333848,
#          6.64043789,   1.98718175, -17.09094547])

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=10)

# %%
ridge_model.fit(scaled_X_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
test_predictions = ridge_model.predict(scaled_X_test)

# %%
MAE = mean_absolute_error(y_test,test_predictions)
MSE = mean_squared_error(y_test,test_predictions)
RMSE = np.sqrt(MSE)

# %%
print(MAE , " ",RMSE)
# Out:
# 8.382260487410594   11.405898191341526

# %%
from sklearn.linear_model import RidgeCV

# %%
ridge_cv_model = RidgeCV(alphas=(0.1, 1.0, 10.0,20,30,50,100,200,400),scoring='neg_mean_absolute_error')

# %%
ridge_cv_model.fit(scaled_X_train,y_train)
# Out:
# RidgeCV(alphas=(0.1, 1.0, 10.0, 20, 30, 50, 100, 200, 400),
#         scoring='neg_mean_absolute_error')

# %%
ridge_cv_model.alpha_
# Out:
# 20.0

# %%
test_predictions = ridge_cv_model.predict(scaled_X_test)

# %%
MAE = mean_absolute_error(y_test,test_predictions)
MSE = mean_squared_error(y_test,test_predictions)
RMSE = np.sqrt(MSE)

# %%
print(MAE , " ",RMSE)
# Out:
# 8.38037788682051   11.407873410922685

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import ElasticNet

# %%
base_elastic_model = ElasticNet(max_iter=1000000)

# %%
param_grid = {'alpha':[0.1,1,5,10,50,100],
              'l1_ratio':[.1, .5, .7, .9, .95, .99, 1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator=base_elastic_model,
                          param_grid=param_grid,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1)

# %%
grid_model.fit(scaled_X_train,y_train)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# GridSearchCV(cv=5, estimator=ElasticNet(max_iter=1000000),
#              param_grid={'alpha': [0.1, 1, 5, 10, 50, 100],
#                          'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
grid_model.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 1}

# %%
#Evaluation du modele

# %%
y_pred = grid_model.predict(scaled_X_test)

# %%
MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RMSE = np.sqrt(MSE)

# %%
np.mean(df['Calories'])
# Out:
# 89.53953333333334

# %%
print(MAE , " " ,RMSE)
# Out:
# 8.374917182202244   11.424552928789028

# %%
#Dernier Modele : Modele optimale?
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree=2,include_bias=False)

# %%
poly_features = polynomial_converter.fit_transform(X)

# %%
poly_features
# Out:
# array([[0.00000e+00, 6.80000e+01, 1.90000e+02, ..., 1.10250e+04,
#         4.28400e+03, 1.66464e+03],
#        [1.00000e+00, 2.00000e+01, 1.66000e+02, ..., 8.83600e+03,
#         3.78820e+03, 1.62409e+03],
#        [0.00000e+00, 6.90000e+01, 1.79000e+02, ..., 7.74400e+03,
#         3.40560e+03, 1.49769e+03],
#        ...,
#        [1.00000e+00, 4.30000e+01, 1.59000e+02, ..., 8.10000e+03,
#         3.60900e+03, 1.60801e+03],
#        [0.00000e+00, 7.80000e+01, 1.93000e+02, ..., 7.05600e+03,
#         3.21720e+03, 1.46689e+03],
#        [0.00000e+00, 6.30000e+01, 1.73000e+02, ..., 8.46400e+03,
#         3.72600e+03, 1.64025e+03]])

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.2, random_state=2)
    
model = LinearRegression()
model.fit(X_train , y_train)
    
train_pred= model.predict(X_train)    
test_pred = model.predict(X_test)

mse =mean_absolute_error(y_test,test_pred)
rmse = np.sqrt(mean_squared_error(y_test , test_pred))

# %%
print(mse," ",rmse)
# Out:
# 2.2420373783303558   3.029550993962044

# %%
train_rmse_errors = []
test_rmse_errors = []


for d in range(1,10):
    poly_converter = PolynomialFeatures(degree=d,include_bias =False)
    poly_features = poly_converter.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.2, random_state=2)
    
    model = LinearRegression()
    model.fit(X_train , y_train)
    
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)
    
    train_rmse = np.sqrt(mean_squared_error(y_train , train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test , test_pred))
    
    train_rmse_errors.append(train_rmse)
    test_rmse_errors.append(test_rmse)

# %%
train_rmse_errors
# Out:
# [11.288109179220815,
#  2.977600937290294,
#  0.2899225746883572,
#  0.28782249435163876,
#  0.28333912474254586,
#  0.29747045245718556,
#  0.559486112522396,
#  0.25269529872821217,
#  0.2375083607640479]

# %%
test_rmse_errors
# Out:
# [11.405572053250273,
#  3.029550993962044,
#  0.2906573310421473,
#  0.29452475596965544,
#  0.3028104546833138,
#  0.5448626412697276,
#  1.4921742156438809,
#  4.152435917290641,
#  6.1321104739841505]

# %%
plt.plot(range(1,10),train_rmse_errors[:],label = 'RMSE de TRAIN')
plt.plot(range(1,10),test_rmse_errors[:],label = 'RMSE de TEST')
plt.xlabel('degré de polynome')
plt.ylabel('RMSE')
plt.legend()

# %%
final_poly_converter = PolynomialFeatures(degree=4,include_bias=False)

# %%
better_model = LinearRegression()

# %%
full_converted_X = final_poly_converter.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(full_converted_X, y, test_size=0.2, random_state=2)

# %%
final_model = LinearRegression()

# %%
final_model.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
train_pred = final_model.predict(X_train)
test_pred = final_model.predict(X_test)

# %%
### Évaluation du modèle

# %%
mean_absolute_error(y_test,test_pred)
# Out:
# 0.25434515544869163

# %%
#RMSE
np.sqrt(mean_squared_error(y_test,test_pred))
# Out:
# 0.29452475596965544

# %%
np.mean(df['Calories'])
# Out:
# 89.53953333333334

# %%
# TRY TO VISUALIZE THIS ERRORS

# %%
train_type = ['train'] * len(train_pred)
test_type = ['test'] * len(test_pred)

# %%
# Now, we concatenate the predictions and their types
predictions = np.concatenate((train_pred, test_pred))
types = np.concatenate((train_type, test_type))

# %%
# Finally, we create the DataFrame
dff = pd.DataFrame({'Type': types, 'Prediction': predictions})
dff
# Out:
#         Type  Prediction
# 0      train   11.844465
# 1      train   36.639019
# 2      train   30.746009
# 3      train  221.645024
# 4      train  174.161563
# ...      ...         ...
# 14995   test  176.683913
# 14996   test   49.062626
# 14997   test  144.703455
# 14998   test   24.017466
# 14999   test   90.255527
#
# [15000 rows x 2 columns]

# %%
df['Prediction_Features'] =dff['Prediction']
df
# Out:
#         User_ID  Gender  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  \
# 0      14733363       0   68   190.0    94.0      29.0       105.0       40.8
# 1      14861698       1   20   166.0    60.0      14.0        94.0       40.3
# 2      11179863       0   69   179.0    79.0       5.0        88.0       38.7
# 3      16180408       1   34   179.0    71.0      13.0       100.0       40.5
# 4      17771927       1   27   154.0    58.0      10.0        81.0       39.8
# ...         ...     ...  ...     ...     ...       ...         ...        ...
# 14995  15644082       1   20   193.0    86.0      11.0        92.0       40.4
# 14996  17212577       1   27   165.0    65.0       6.0        85.0       39.2
# 14997  17271188       1   43   159.0    58.0      16.0        90.0       40.1
# 14998  18643037       0   78   193.0    97.0       2.0        84.0       38.3
# 14999  11751526       0   63   173.0    79.0      18.0        92.0       40.5
#
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Gender', 'Age', 'Height', 'Weight', 'Duration',
#        'Heart_Rate', 'Body_Temp', 'Calories', 'Prediction_Features'],
#       dtype='object')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(10,4))


axes[0].plot(df['Age'],df['Calories'],'o')
axes[0].plot(df['Age'],df['Prediction_Features'],'o',color='red')
axes[0].set_title("Approx Age")
axes[0].set_ylabel("Calories")

axes[1].plot(df['Height'],df['Calories'],'o')
axes[1].plot(df['Height'],df['Prediction_Features'],'o',color='red')
axes[1].set_title("Approx Height")
axes[1].set_ylabel("Calories")

plt.tight_layout();

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(10,4))

axes[0].plot(df['Weight'],df['Calories'],'o')
axes[0].plot(df['Weight'],df['Prediction_Features'],'o',color='red')
axes[0].set_title("Approx Weight")
axes[0].set_ylabel("Calories")

axes[1].plot(df['Duration'],df['Calories'],'o')
axes[1].plot(df['Duration'],df['Prediction_Features'],'o',color='red')
axes[1].set_title("Approx Duration")
axes[1].set_ylabel("Calories")
plt.tight_layout();

# %%
fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(10,4))

axes[0].plot(df['Heart_Rate'],df['Calories'],'o')
axes[0].plot(df['Heart_Rate'],df['Prediction_Features'],'o',color='red')
axes[0].set_title("Approx Heart_Rate")
axes[0].set_ylabel("Calories")

axes[1].plot(df['Body_Temp'],df['Calories'],'o')
axes[1].plot(df['Body_Temp'],df['Prediction_Features'],'o',color='red')
axes[1].set_title("Approx Body_Temp")
axes[1].set_ylabel("Calories")
plt.tight_layout();

# %%
fig,axes = plt.subplots(nrows=1,ncols=1,figsize=(10,4))

axes.plot(df['Gender'],df['Calories'],'o')
axes.plot(df['Gender'],df['Prediction_Features'],'o',color='red')
axes.set_title("Approx Gender")
axes.set_ylabel("Calories")
# Out:
# Text(0, 0.5, 'Calories')

# %%
#END
